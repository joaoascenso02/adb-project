# %% [markdown]
# # **BDA - Phase 1**

# %% [markdown]
# ### **MongoDB**

# %%
import pandas as pd
import time

# %%
# host_df = pd.read_csv('../data/clean-data/host.csv', dtype={
#     'id': 'int',
#     'url': 'str',
#     # other columns 
# })

# might need to define data types

# %%
host_df = pd.read_csv('../data/clean-data/host.csv')
host_statistics_df = pd.read_csv('../data/clean-data/host_statistics.csv')
listings_df = pd.read_csv('../data/clean-data/listings.csv')
calendar_df = pd.read_csv('../data/clean-data/calendar.csv')
reviews_df = pd.read_csv('../data/clean-data/reviews.csv')
availability_statistics_df = pd.read_csv('../data/clean-data/availability_statistics.csv')
reviews_statistics_df = pd.read_csv('../data/clean-data/reviews_statistics.csv')

# %%
from pymongo import MongoClient
import json

# %%
client =MongoClient('mongodb+srv://dbUser:password@somecluster.rrxnu.mongodb.net/?retryWrites=true&w=majority&appName=NORA')
client.drop_database("Project_DB")
print("Database dropped")
db = client["Project_DB"]
# Out:
# Database dropped

# %% [markdown]
# ### Database Creation Block

# %%
db['Hosts'].drop()
print("Collection dropped")
host=db.create_collection("Hosts",validator={
    '$jsonSchema':{
        'bsonType':'object',
        'required':['id','url','name','is_superhost','verifications','location'],
        'properties':{
            'id':{
                'bsonType':'int',
                'description':'must be a valid 16-bit integer (required)'
            },
            'url':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'name':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'about':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'is_superhost':{
                'bsonType':'bool',
                'description':'must be a valid boolean (required)'
            },
            'thumbnail_url':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'picture_url':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'verifications':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'location':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'neighbourhood':{
                'bsonType':'string',
                'description':'must be a valid string'
            }        
        }
    }    
})
# Out:
# Collection dropped

# %%
db['Listings'].drop()
print("Collection dropped")
list=db.create_collection("Listings",validator={
    '$jsonSchema':{
        'bsonType':'object',
        'required':['id','base_price','instant_bookable','has_availability',
                    'minimum_nights','maximum_nights','name','description',
                    'neighborhood_overview','neighbourhood',
                    'latitude','longitude','bathrooms','property_type',
                    'room_type','accommodates','bedrooms','beds','amenities'
                    ],
        'properties':{
            'id':{
                'bsonType':'number',
                'description':'must be a valid numerical value (required)'
            },
            'base_price':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double (required)'
            },
            'instant_bookable':{
                'bsonType':'bool',
                'description':'must be a valid boolean (required)'
            },
            'has_availability':{
                'bsonType':'bool',
                'description':'must be a valid boolean (required)'
            },
            'minimum_nights':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'maximum_nights':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'last_scraped':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'picture_url':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'listing_url':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'name':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'description':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'neighborhood_overview':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'neighbourhood':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'latitude':{
                'bsonType':'double',
                'description':'must be a valid double (required)'
            },
            'longitude':{
                'bsonType':'double',
                'description':'must be a valid double (required)'
            },
            'bathrooms':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double (required)'
            },
            'bathrooms_text':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'property_type':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'room_type':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'accomodates':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'bedrooms':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double (required)'
            },
            'beds':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double (required)'
            },
            'amenities':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
        }
    }    
})
# Out:
# Collection dropped

# %%
db['Host_Statistics'].drop()
print("Collection dropped")

host_S=db.create_collection("Host_Statistics",validator={
    '$jsonSchema':{
        'bsonType':'object',
        'required':['response_time','response_rate','acceptance_rate','listings_count'],
        'properties':{
            'id':{
                'bsonType':'int',
                'description':'must be a valid 16-bit integer'
            },
            'since:':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'response_time':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'response_rate':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double (required)'
            },
            'listings_count':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'total_listings_count':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'calculated_host_listings_count':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'calculated_host_listings_count_entire_homes':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'calculated_host_listings_count_private_rooms':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'calculated_host_listings_count_shared_rooms':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
        }
    }
})
# Out:
# Collection dropped

# %%
db['Calendar'].drop()
print("Collection dropped")

calend=db.create_collection("Calendar",validator={
    '$jsonSchema':{
        'bsonType':'object',
        'required':['date','available','price'],
        'properties':{
            'id':{
                'bsonType':'int',
                'description':'must be a valid 16-bit integer'
            },
            'date:':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'available':{
                'bsonType':'bool',
                'description':'must be a valid boolean (required)'
            },
            'price':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double (required)'
            }
        }
    }
})
# Out:
# Collection dropped

# %%
db['Reviews'].drop()
print("Collection dropped")

revi=db.create_collection("Reviews",validator={
    '$jsonSchema':{
        'bsonType':'object',
        'required':['date','reviewer_name','comments'],
        'properties':{
            'id':{
                'bsonType':'number',
                'description':'must be a valid numerical value'
            },
            'date:':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'reviewer_id':{
                'bsonType':'int',
                'description':'must be a valid 16-bit integer'
            },
            'reviewer_name':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            },
            'comments':{
                'bsonType':'string',
                'description':'must be a valid string (required)'
            }

        }
    }
})
# Out:
# Collection dropped

# %%
db['Availability_Statistics'].drop()
print("Collection dropped")

av_S=db.create_collection("Availability_Statistics",validator={
    '$jsonSchema':{
        'bsonType':'object',
        'required':['availability_30','availability_60',
                    'availability_90','availability_365'],
        'properties':{
            'id':{
                'bsonType':'number',
                'description':'must be an integer'
            },
            'availability_30':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'availability_60':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'availability_90':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'availability_365':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'minimum_minimum_nights':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a 16-bit valid integer'
            },
            'maximum_minimum_nights':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'minimum_maximum_nights':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'maximum_maximum_nights':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'minimum_nights_avg_ntm':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double'
            },
            'maximum_nights_avg_ntm':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double'
            }

        }
    }
})
# Out:
# Collection dropped

# %%
db['Reviews_Statistics'].drop()
print("Collection dropped")

revi_S=db.create_collection("Reviews_Statistics",validator={
    '$jsonSchema':{
        'bsonType':'object',
        'required':['number_of_reviews','review_scores_value'],
        'properties':{
            'id':{
                'bsonType':'number',
                'description':'must be a valid numerical value'
            },
            'number_of_reviews':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer (required)'
            },
            'number_of_reviews_ltm':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'number_of_reviews_l30d':{
                'bsonType':'int',
                'minimum':0,
                'description':'must be a valid 16-bit integer'
            },
            'first_review':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'last_review':{
                'bsonType':'string',
                'description':'must be a valid string'
            },
            'scores_rating':{
                'bsonType':'decimal',
                'minimum':0,
                'description':'must be a valid decimal'
            },
            'scores_accuracy':{
                'bsonType':'decimal',
                'minimum':0,
                'description':'must be a valid decimal'
            },
            'scores_cleanliness':{
                'bsonType':'decimal',
                'minimum':0,
                'description':'must be a valid decimal'
            },
            'review_scores_checkin':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double'
            },
            'review_scores_communication':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double'
            },
            'review_scores_location':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double'
            },
            'review_scores_value':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double'
            },
            'reviews_per_month':{
                'bsonType':'double',
                'minimum':0,
                'description':'must be a valid double'
            }
        }
    }
})
# Out:
# Collection dropped

# %%
def mongoimport(csv_path,coll_name):
    """ Imports a csv file at path csv_name to a mongo colection
    returns: count of the documants in the new collection
    """
    data = pd.read_csv(csv_path)
    payload = json.loads(data.to_json(orient='records'))
    #coll.insert_many(payload)
    count = coll_name.count_documents({})
    print(f"# documents: {count}") 
    try:
        coll_name.insert_many(payload, ordered=False)

    except Exception:
        attempted_count = len(payload)
        valid_count = coll_name.count_documents({}) - count
        print(f"{valid_count} documents inserted.")
        print(f"{attempted_count - valid_count} documents failed to insert.")
    print(f"# documents: {coll_name.count_documents({})}")

# %%
mongoimport('../data/clean-data/host.csv',host)
mongoimport('../data/clean-data/listings.csv',list)
mongoimport('../data/clean-data/calendar.csv',calend)
mongoimport('../data/clean-data/reviews.csv',revi)
mongoimport('../data/clean-data/host_statistics.csv',host_S)
mongoimport('../data/clean-data/availability_statistics.csv',av_S)
mongoimport('../data/clean-data/reviews_statistics.csv',revi_S)
# Out:
# # documents: 0
# # documents: 426
# # documents: 0
# # documents: 426
# # documents: 0
# # documents: 155490
# # documents: 0
# # documents: 24752
# # documents: 0
# # documents: 426
# # documents: 0
# # documents: 426
# # documents: 0
# # documents: 426

# %%
db.Hosts.aggregate([
    {'$lookup': {
        'from': 'Listings',
        'localField': 'id',
        'foreignField': 'host_id',
        'as': 'Listings'
    }},
    {'$lookup': {
        'from': 'Host_Statistics',
        'localField': 'id',
        'foreignField': 'host_id',
        'as': 'Statistics'
    }},
    {'$out': "Hosts"}
])


db.Listings.aggregate([
    {'$lookup': {
        'from': 'Calendar',
        'localField': 'id',
        'foreignField': 'listing_id',
        'as': 'Calendar'
    }},
    {'$lookup': {
        'from': 'Reviews',
        'localField': 'id',
        'foreignField': 'listing_id',
        'as': 'Reviews'
    }},
    {'$lookup': {
        'from': 'Reviews_Statistics',
        'localField': 'id',
        'foreignField': 'listing_id',
        'as': 'Review_Statistics'
    }},
    {'$lookup': {
        'from': 'Availability_Statistics',
        'localField': 'id',
        'foreignField': 'listing_id',
        'as': 'Availability Statistics'
    }},


    {'$out': "Listings"}
])

# %% [markdown]
# ### Query Block

# %%
# available 2 bedrooms airbnbs with price lower then 100 (Simple Query)

simple_query = {
    "bedrooms": {"$eq": 2},
    "base_price": {"$lt": 100},
    "has_availability": True
}
result = db.Listings.find(simple_query)

explain_output = result.explain()
execution_time = explain_output['executionStats']['executionTimeMillis']
num_results = explain_output['executionStats']['nReturned']

print(f"Execution Time: {execution_time} ms")
print(f"Number of Results: {num_results}")
# Out:
# Execution Time: 0 ms
# Number of Results: 17

# %%
#Search available hosts, calculate the mean base price of their listings.
#Match the hosts that reside in New York with more than 5 listings and an average listing price less than 150 dollars.
#Complex Query
def host_query(toPrintOutput=False): 
    try:
        pipeline = [
            
            {
                '$lookup': {
                    'from': 'Listings',  
                    'localField': 'id',  
                    'foreignField': 'host_id',  
                    'as': 'listings'
                }
            },
            {
                '$addFields': {
                    'listings_available': {
                        '$filter': {
                            'input': '$Listings',
                            'as': 'listing',
                            'cond': {'$eq': ['$$listing.has_availability', True]}
                        }
                    }
                }
            },
            
            {
                '$addFields': {
                    'average_price': {
                        '$cond': [
                            {'$gt': [{'$size': '$listings_available'}, 0]},
                            {
                                '$avg': {
                                    '$map': {
                                        'input': '$listings_available',  
                                        'as': 'listing',  
                                        'in': '$$listing.base_price'  
                                    }
                                }
                            },
                            None  
                        ]
                    }
                }
            },
            
            {
                '$lookup': {
                    'from': 'Host_Statistics', 
                    'localField': 'id',
                    'foreignField': 'host_id',
                    'as': 'host_stats'
                }
            },
            {
                '$addFields': {
                    'listings_count': {'$arrayElemAt': ['$host_stats.listings_count', 0]}
                }
            },
            {
                '$match': {
                    'listings_count': {'$gt': 5},
                    'average_price': {'$lt': 150},
                    'location': 'New York, NY'
                }
            },
            {
                '$project': {
                    'host_id': '$id',
                    'host_name': '$name',
                    'host_location': '$location',
                    'average_price': 1,
                    'listings_count': 1
                }
            },
            {
                '$sort': {'average_price': 1}
            }
        ]

        results = db.Hosts.aggregate(pipeline)
        results_list = results.to_list()

        print(f"\n# Results: {len(results_list)}")
        if toPrintOutput:
            for result in results_list:
                print(result)

    except Exception as e:
        print(f"Error querying: {e}")

host_query(toPrintOutput=True)
# Out:
# # Results: 9
# {'_id': ObjectId('674cdbe1c2008db7821fe33b'), 'average_price': 102.16666666666667, 'listings_count': 8, 'host_id': 42708277, 'host_name': 'Rodney', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe345'), 'average_price': 102.16666666666667, 'listings_count': 8, 'host_id': 42708277, 'host_name': 'Rodney', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe383'), 'average_price': 102.16666666666667, 'listings_count': 8, 'host_id': 42708277, 'host_name': 'Rodney', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe384'), 'average_price': 102.16666666666667, 'listings_count': 8, 'host_id': 42708277, 'host_name': 'Rodney', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe385'), 'average_price': 102.16666666666667, 'listings_count': 8, 'host_id': 42708277, 'host_name': 'Rodney', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe396'), 'average_price': 102.16666666666667, 'listings_count': 8, 'host_id': 42708277, 'host_name': 'Rodney', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe2e6'), 'average_price': 103.0, 'listings_count': 7, 'host_id': 110453341, 'host_name': 'Alexis', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe25a'), 'average_price': 104.5, 'listings_count': 7, 'host_id': 385664127, 'host_name': 'Dillon', 'host_location': 'New York, NY'}
# {'_id': ObjectId('674cdbe1c2008db7821fe25c'), 'average_price': 104.5, 'listings_count': 7, 'host_id': 385664127, 'host_name': 'Dillon', 'host_location': 'New York, NY'}

# %%
#Simple Query
def host_query(query, toPrintOutput = False):
    try:
        # Execute the query
        result = db.Hosts.find(query)
        result_count = db.Hosts.count_documents(query)
        
        # Print the count of results
        print(f"\n# Results: {result_count}")
        # Print the results if toPrintOutput is True
        if toPrintOutput:
            for output in result:
                print(output)

    except Exception as e:
        print(f"Error querying: {e}")

start_time = time.time()
host_query({'location': 'Albany, NY', 'Statistics.listings_count': {'$gt': 1}}) #This query searches for all hosts in Albany, NY with more than one listing in the database.
end_time = time.time()
print(f"Query done in {end_time - start_time:.4f} seconds")
# Out:
# # Results: 262
# Query done in 0.0493 seconds

# %%
#Complex Query
# Start the timer
start_time = time.time()

# Perform the update query in MongoDB
result = db.Listings.update_many(
    {
        "has_availability": True,  # Only listings with availability
        "base_price": {"$lt": 300},  # Base price must be less than 300
        "Review_Statistics.number_of_reviews": {"$gt": 10},  # More than 10 reviews
        "Review_Statistics.review_scores_rating": {"$gt": 4.5}  # Review score greater than 4.5
    },
    {
        "$mul": {"base_price": 1.1}  # Increase the base_price by 10%
    }
)

# End the timer
end_time = time.time()

# Print the number of documents updated and the time taken
affected_documents = result.modified_count
print(f"{affected_documents} documents updated in {end_time - start_time:.4f} seconds")
# Out:
# 235 documents updated in 0.1506 seconds
